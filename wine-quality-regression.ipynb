# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import zscore

# %% [markdown]
# # Dataset Exploration

# %%
df = pd.read_csv("../input/red-wine-quality-cortez-et-al-2009/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# # Duplicates Removal

# %%
df = df.drop_duplicates()
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1359 rows x 12 columns]

# %% [markdown]
# # Examine Target Column - Quality

# %% [markdown]
# We're missing data about vines whose quality is: 1, 2, 9, 10. This indicates that we might have problem predicting vines from this values (for examples not from the dataset).

# %%
qualities = df.quality.sort_values().unique()
qualities
# Out:
# array([3, 4, 5, 6, 7, 8])

# %% [markdown]
# The data is also extremely imbalanced: we have many wines whose quality is 5-6, but very small number of wines whose quality is 3, 8.

# %%
sns.countplot(x="quality", data=df).set_title("Wine distribution by quality")
# Out:
# Text(0.5, 1.0, 'Wine distribution by quality')

# %%
(df.quality.value_counts(normalize=True) * 100)
# Out:
# 5    42.457689
# 6    39.367182
# 7    12.288447
# 4     3.899926
# 8     1.250920
# 3     0.735835
# Name: quality, dtype: float64

# %% [markdown]
# # Examine columns

# %% [markdown]
# ## Fixed acidity

# %% [markdown]
# Most acids involved with wine or fixed or nonvolatile.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["fixed acidity"], color='teal').set(title='Fixed Acidity Boxplot')
# Out:
# [Text(0.5, 1.0, 'Fixed Acidity Boxplot')]

# %% [markdown]
# Higher quality of wine tend to have **higher** levels of 'fixed acidity':

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["fixed acidity"].plot.kde(label="quality 3-4").set(title='Fixed Acidity Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["fixed acidity"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["fixed acidity"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## Volatile acidity

# %% [markdown]
# The amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["volatile acidity"], color='teal').set(title='Volatile Acidity Boxplot')
# Out:
# [Text(0.5, 1.0, 'Volatile Acidity Boxplot')]

# %% [markdown]
# Higher quality wines tend to have **lower** levels of 'volatile acidity':

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["volatile acidity"].plot.kde(label="quality 3-4").set(title='Volatile Acidity Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["volatile acidity"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["volatile acidity"].plot.kde(label="quality 7-8")
plt.legend()

# %%
sns.barplot(x='quality',y='volatile acidity',data=df).set_title("Volatile acidity value impact on wine quality")
# Out:
# Text(0.5, 1.0, 'Volatile acidity value impact on wine quality')

# %% [markdown]
# ## Citric acid

# %% [markdown]
# Found in small quantities, citric acid can add 'freshness' and flavor to wines.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["citric acid"], color='teal').set(title='Citric Acidity Boxplot')
# Out:
# [Text(0.5, 1.0, 'Citric Acidity Boxplot')]

# %% [markdown]
# Higher quality wines tend to have higher values of 'citric acid':

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["citric acid"].plot.kde(label="quality 3-4").set(title='Citric Acidity Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["citric acid"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["citric acid"].plot.kde(label="quality 7-8")
plt.legend()

# %%
sns.barplot(x='quality',y='citric acid',data=df).set_title("Citric acid value impact on wine quality")
# Out:
# Text(0.5, 1.0, 'Citric acid value impact on wine quality')

# %% [markdown]
# ## Residual sugar

# %% [markdown]
# The amount of sugar remaining after fermentation stops, it's rare to find wines with less than 1 gram/liter and wines with greater than 45 grams/liter are considered sweet.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["residual sugar"], color='teal').set(title='Residual Sugar Boxplot')
# Out:
# [Text(0.5, 1.0, 'Residual Sugar Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["residual sugar"].plot.kde(label="quality 3-4").set(title='Residual Sugar Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["residual sugar"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["residual sugar"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## Chlorides

# %% [markdown]
# The amount of salt in the wine.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["chlorides"], color='teal').set(title='Chlorides Boxplot')
# Out:
# [Text(0.5, 1.0, 'Chlorides Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["chlorides"].plot.kde(label="quality 3-4").set(title='Chlorides Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["chlorides"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["chlorides"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## Free sulfur dioxide

# %% [markdown]
# The free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion; it prevents microbial growth and the oxidation of wine.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["free sulfur dioxide"], color='teal').set(title='Free Sulfur Dioxide Boxplot')
# Out:
# [Text(0.5, 1.0, 'Free Sulfur Dioxide Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["free sulfur dioxide"].plot.kde(label="quality 3-4").set(title='Free Sulfur Dioxide Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["free sulfur dioxide"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["free sulfur dioxide"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## Total sulfur dioxide

# %% [markdown]
# Amount of free and bound forms of S02; in low concentrations, SO2 is mostly undetectable in wine, but at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["total sulfur dioxide"], color='teal').set(title='Total Sulfur Dioxide Boxplot')
# Out:
# [Text(0.5, 1.0, 'Total Sulfur Dioxide Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["total sulfur dioxide"].plot.kde(label="quality 3-4").set(title='Total Sulfur Dioxide Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["total sulfur dioxide"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["total sulfur dioxide"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## Density

# %% [markdown]
# The density of water is close to that of water depending on the percent alcohol and sugar content.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["density"], color='teal').set(title='Density Boxplot')
# Out:
# [Text(0.5, 1.0, 'Density Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["density"].plot.kde(label="quality 3-4").set(title='"Density" Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["density"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["density"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## pH

# %% [markdown]
# Describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic); most wines are between 3-4 on the pH scale.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["pH"], color='teal').set(title='pH Boxplot')
# Out:
# [Text(0.5, 1.0, 'pH Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["pH"].plot.kde(label="quality 3-4").set(title='pH Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["pH"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["pH"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# ## Sulphates

# %% [markdown]
# A wine additive which can contribute to sulfur dioxide gas (S02) levels, wich acts as an antimicrobial and antioxidant.

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.boxplot(x=df["sulphates"], color='teal').set(title='Sulphates Boxplot')
# Out:
# [Text(0.5, 1.0, 'Sulphates Boxplot')]

# %%
sns.set(rc={'figure.figsize':(12,5)})
df[(df["quality"] == 3) | (df["quality"] == 4)]["sulphates"].plot.kde(label="quality 3-4").set(title='Sulphates Density Graph')
df[(df["quality"] == 5) | (df["quality"] == 6)]["sulphates"].plot.kde(label="quality 5-6")
df[(df["quality"] == 7) | (df["quality"] == 8)]["sulphates"].plot.kde(label="quality 7-8")
plt.legend()

# %% [markdown]
# # Correlation

# %%
sns.set(rc={'figure.figsize':(10,5)})
corr = df.corr().sort_values(ascending=False, key=lambda x: abs(x), by="quality")

print("Correlation to 'quality' value:")
print (corr["quality"])

ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_title("Wine Quality Heatmap")
# Out:
# Correlation to 'quality' value:
# quality                 1.000000
# alcohol                 0.480343
# volatile acidity       -0.395214
# sulphates               0.248835
# citric acid             0.228057
# density                -0.184252
# total sulfur dioxide   -0.177855
# chlorides              -0.130988
# fixed acidity           0.119024
# pH                     -0.055245
# free sulfur dioxide    -0.050463
# residual sugar          0.013640
# Name: quality, dtype: float64
# Text(0.5, 1.0, 'Wine Quality Heatmap')

# %% [markdown]
# From the heatmap we can learn that high-quality vines tend to have:
# 1. **High** alcohol percentage
# 2. **Low** volatile acidity
# 3. **High** sulphates
# 4. **High** citric acid

# %% [markdown]
# # Drop columns

# %% [markdown]
# We should also consider removing the columns that have low correlation with the quality column:
# 1. pH
# 2. free sulfur dioxide
# 3. residual sugar

# %%
df = df.drop(columns=["pH", "free sulfur dioxide", "residual sugar"])

# %% [markdown]
# # Standartization

# %% [markdown]
# Perform stadartization (to normal distribution: N~(0, 1))

# %%
standarized_df = round((df-df.mean())/df.std(), 3)
standarized_df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0            -0.524             0.932       -1.393     -0.246
# 1            -0.294             1.915       -1.393      0.200
# 2            -0.294             1.259       -1.188      0.079
# 3             1.663            -1.363        1.471     -0.266
# 5            -0.524             0.713       -1.393     -0.266
# ...             ...               ...          ...        ...
# 1593         -0.870             0.495       -0.984     -0.408
# 1594         -1.215             0.385       -0.984      0.038
# 1595         -1.388             0.112       -0.881     -0.529
# 1597         -1.388             0.631       -0.779     -0.266
# 1598         -1.330            -1.199        1.011     -0.428
#
#       total sulfur dioxide  density  sulphates  alcohol  quality
# 0                   -0.384    0.584     -0.578   -0.954   -0.757
# 1                    0.604    0.049      0.125   -0.584   -0.757
# 2                    0.215    0.156     -0.051   -0.584   -0.757
# 3                    0.394    0.691     -0.461   -0.584    0.457
# 5                   -0.204    0.584     -0.578   -0.954   -0.757
# ...                    ...      ...        ...      ...      ...
# 1593                -0.264   -0.106      0.945   -0.862    0.457
# 1594                -0.085   -0.968     -0.461    0.063   -0.757
# 1595                 0.125   -0.850      0.594    0.709    0.457
# 1597                -0.085   -0.663      0.301   -0.215   -0.757
# 1598                -0.144   -0.652      0.008    0.525    0.457
#
# [1359 rows x 9 columns]

# %%
sns.set(rc={'figure.figsize':(25,15)})
standarized_df.boxplot().set(title='Standarized Wine Quality Data Boxplots')
# Out:
# [Text(0.5, 1.0, 'Standarized Wine Quality Data Boxplots')]

# %% [markdown]
# # Train Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from numpy import round

df_train = standarized_df.drop(columns=["quality"])
X_train, X_test, y_train, y_test = train_test_split(df_train,df["quality"],test_size=0.2,shuffle=True, stratify=df["quality"])

pipeline =  LinearRegression()
pipeline.fit(X_train, y_train)

predictions = pipeline.predict(X_test)
print(f"Mean Absolute Error(MAE): {mean_absolute_error(y_test, round(predictions, 0))}")
print(f"Mean Squared Error(MSE): {mean_squared_error(y_test, round(predictions, 0))}")
print(f"R2 Score: {r2_score(y_test, round(predictions, 0))}")
# Out:
# Mean Absolute Error(MAE): 0.44485294117647056
# Mean Squared Error(MSE): 0.5036764705882353
# R2 Score: 0.24917894058149137
